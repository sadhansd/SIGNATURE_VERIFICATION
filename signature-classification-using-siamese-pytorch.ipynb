# %% [markdown]
# # Siamese Neural Network
#
# Siamese neural network is a class of neural network architectures that contain two or more identical sub networks. identical here means they have the same configuration with the same parameters and weights. Parameter updating is mirrored across both sub networks.It is used find the similarity of the inputs by comparing its feature vectors.

# %% [markdown]
# ## Steps to create classifier using Siamese Neural Network
#
#
# 1.   **Data Preprocessing**
# 2.   **Define the Siamese Network**
# 3.   **Feature Vector Extraction**
# 4.   **Similarity Score Calculation**
# 5.   **Defininf Loss Function**
# 6.   **Optimizer**
# 7.   **Testing using One-Shot Learnig**
# 8.   **Making Predictions**

# %% [markdown]
# ## Import and Install all the necessary packages

# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Additional Utility Functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# First, look at everything.
from subprocess import check_output
print(check_output(["ls", "/content/drive/MyDrive/dataset/sign_data"]).decode("utf8"))
# Out:
# sign_data
# test
# test_data.csv
# train
# train_data.csv

# %%
class Config():
    training_dir = "/content/drive/MyDrive/dataset/sign_data/train"
    testing_dir = "/content/drive/MyDrive/dataset/sign_data/test"
    train_batch_size = 32
    train_number_epochs = 20

# %% [markdown]
# ## Load Dataset :
#
# Datasets can be downloaded from this Link:  https://drive.google.com/file/d/1q03FLpaolm6Jq5vM0a_AEnjJoqjtxgP8/view?usp=sharing
#
# **Copy the dataset directly to your drive and load it from there**

# %%
training_dir="/content/drive/MyDrive/dataset/sign_data/train"
training_csv="/content/drive/MyDrive/dataset/sign_data/train_data.csv"
testing_csv="/content/drive/MyDrive/dataset/sign_data/test_data.csv"
testing_dir="/content/drive/MyDrive/dataset/sign_data/test"

# %% [markdown]
# ### Preprocessing and Loading Dataset
#
# We preprocessed all the images and loaded them as .npy files which is easy to transfer . You can follow your own preprocessing steps .

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
# Load the the dataset from raw image folders
siamese_dataset = SiameseNetworkDataset(training_csv,training_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %% [markdown]
# ## Siamese Network Definition

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            
            nn.Conv2d(1, 96, kernel_size=11,stride=1),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5,stride=1,padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

            nn.Conv2d(256,384 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384,256 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

        )
        
        # Defining the fully connected layers
        self.fc1 = nn.Sequential(
            nn.Linear(30976, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout2d(p=0.5),
            
            nn.Linear(1024, 128),
            nn.ReLU(inplace=True),
            
            nn.Linear(128,2))
        
  
  
    def forward_once(self, x):
        # Forward pass 
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # forward pass of input 1
        output1 = self.forward_once(input1)
        # forward pass of input 2
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ### Loss Function

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ### Train the Model

# %%
# Load the dataset as pytorch tensors using dataloader
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# Check whether you have GPU is loaded or not
if torch.cuda.is_available():
    print('Yes')
# Out:
# Yes

# %%
# Declare Siamese Network
net = SiameseNetwork().cuda()
# Decalre Loss Function
criterion = ContrastiveLoss()
# Declare Optimizer
optimizer = optim.RMSprop(net.parameters(), lr=1e-4, alpha=0.99, eps=1e-8, weight_decay=0.0005, momentum=0.9)

# %%
counter = []
loss_history = []
def train():
     
    iteration_number= 0
    
    for epoch in range(0,Config.train_number_epochs):
        for i, data in enumerate(train_dataloader,0):
            img0, img1 , label = data
            img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
            optimizer.zero_grad()
            output1,output2 = net(img0,img1)
            output1,output2 = output1.cuda(), output2.cuda()
            loss_contrastive = criterion(output1,output2,label)
            loss_contrastive = loss_contrastive.cuda()
            loss_contrastive.backward()
            optimizer.step()
            if i %50 == 0 :
                print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
                iteration_number +=10
                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return net

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Train the model
model = train()
torch.save(model.state_dict(), "model.pt")
print("Model Saved Successfully")
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# Epoch number 0
#  Current loss 1.743808388710022
#
# Epoch number 0
#  Current loss 0.9633851051330566
#
# Epoch number 0
#  Current loss 1.1724814176559448
#
# Epoch number 0
#  Current loss 1.1161623001098633
#
# Epoch number 0
#  Current loss 1.0518722534179688
#
# Epoch number 0
#  Current loss 1.1939952373504639
#
# Epoch number 0
#  Current loss 1.1077072620391846
#
# Epoch number 0
#  Current loss 1.2240581512451172
#
# Epoch number 0
#  Current loss 1.2208343744277954
#
# Epoch number 0
#  Current loss 1.0564264059066772
#
# Epoch number 0
#  Current loss 1.2151283025741577
#
# Epoch number 0
#  Current loss 1.0570597648620605
#
# Epoch number 0
#  Current loss 1.2155609130859375
#
# Epoch number 0
#  Current loss 1.2055808305740356
#
# Epoch number 0
#  Current loss 1.3423902988433838
#
# Epoch number 1
#  Current loss 1.1967697143554688
#
# Epoch number 1
#  Current loss 1.2224030494689941
#
# Epoch number 1
#  Current loss 1.1346595287322998
#
# Epoch number 1
#  Current loss 1.0448801517486572
#
# Epoch number 1
#  Current loss 1.121074914932251
#
# Epoch number 1
#  Current loss 1.3011817932128906
#
# Epoch number 1
#  Current loss 1.1629953384399414
#
# Epoch number 1
#  Current loss 1.0957297086715698
#
# Epoch number 1
#  Current loss 1.31484854221344
#
# Epoch number 1
#  Current loss 1.106121301651001
#
# Epoch number 1
#  Current loss 1.4500188827514648
#
# Epoch number 1
#  Current loss 1.7851380109786987
#
# Epoch number 1
#  Current loss 1.482102870941162
#
# Epoch number 1
#  Current loss 1.2260692119598389
#
# Epoch number 1
#  Current loss 1.5104470252990723
#
# Epoch number 2
#  Current loss 1.2918932437896729
#
# Epoch number 2
#  Current loss 1.3104135990142822
#
# Epoch number 2
#  Current loss 1.2416483163833618
#
# Epoch number 2
#  Current loss 1.2897647619247437
#
# Epoch number 2
#  Current loss 1.6231927871704102
#
# Epoch number 2
#  Current loss 0.9601726531982422
#
# Epoch number 2
#  Current loss 1.0633201599121094
#
# Epoch number 2
#  Current loss 1.2878262996673584
#
# Epoch number 2
#  Current loss 0.9701859951019287
#
# Epoch number 2
#  Current loss 1.2486083507537842
#
# Epoch number 2
#  Current loss 1.6377499103546143
#
# Epoch number 2
#  Current loss 1.3866217136383057
#
# Epoch number 2
#  Current loss 1.1644049882888794
#
# Epoch number 2
#  Current loss 1.1907291412353516
#
# Epoch number 2
#  Current loss 1.143970251083374
#
# Epoch number 3
#  Current loss 1.3549895286560059
#
# Epoch number 3
#  Current loss 1.3423398733139038
#
# Epoch number 3
#  Current loss 1.231640100479126
#
# Epoch number 3
#  Current loss 1.3944294452667236
#
# Epoch number 3
#  Current loss 1.2612662315368652
#
# Epoch number 3
#  Current loss 1.2807033061981201
#
# Epoch number 3
#  Current loss 1.2226096391677856
#
# Epoch number 3
#  Current loss 1.1467275619506836
#
# Epoch number 3
#  Current loss 1.2221455574035645
#
# Epoch number 3
#  Current loss 1.0713067054748535
#
# Epoch number 3
#  Current loss 1.5034801959991455
#
# Epoch number 3
#  Current loss 1.3827296495437622
#
# Epoch number 3
#  Current loss 1.4525458812713623
#
# Epoch number 3
#  Current loss 1.1882818937301636
#
# Epoch number 3
#  Current loss 1.331728458404541
#
# Epoch number 4
#  Current loss 1.249682903289795
#
# Epoch number 4
#  Current loss 1.1517505645751953
#
# Epoch number 4
#  Current loss 0.9972081184387207
#
# Epoch number 4
#  Current loss 1.1882128715515137
#
# Epoch number 4
#  Current loss 1.2811295986175537
#
# Epoch number 4
#  Current loss 1.1217765808105469
#
# Epoch number 4
#  Current loss 1.1563774347305298
#
# Epoch number 4
#  Current loss 1.3191239833831787
#
# Epoch number 4
#  Current loss 1.09810471534729
#
# Epoch number 4
#  Current loss 1.1900489330291748
#
# Epoch number 4
#  Current loss 1.3615707159042358
#
# Epoch number 4
#  Current loss 1.2058970928192139
#
# Epoch number 4
#  Current loss 1.3823732137680054
#
# Epoch number 4
#  Current loss 1.223667860031128
#
# Epoch number 4
#  Current loss 1.020391583442688
#
# Epoch number 5
#  Current loss 1.3328403234481812
#
# Epoch number 5
#  Current loss 1.084815502166748
#
# Epoch number 5
#  Current loss 1.2401773929595947
#
# Epoch number 5
#  Current loss 1.2677218914031982
#
# Epoch number 5
#  Current loss 1.10288405418396
#
# Epoch number 5
#  Current loss 1.2155555486679077
#
# Epoch number 5
#  Current loss 1.1831817626953125
#
# Epoch number 5
#  Current loss 1.0544408559799194
#
# Epoch number 5
#  Current loss 1.1991569995880127
#
# Epoch number 5
#  Current loss 1.360375165939331
#
# Epoch number 5
#  Current loss 1.1378990411758423
#
# Epoch number 5
#  Current loss 1.084904432296753
#
# Epoch number 5
#  Current loss 1.072065830230713
#
# Epoch number 5
#  Current loss 1.076901912689209
#
# Epoch number 5
#  Current loss 1.2964750528335571
#
# Epoch number 6
#  Current loss 1.1840345859527588
#
# Epoch number 6
#  Current loss 1.0829005241394043
#
# Epoch number 6
#  Current loss 1.2614362239837646
#
# Epoch number 6
#  Current loss 1.1794699430465698
#
# Epoch number 6
#  Current loss 1.1839455366134644
#
# Epoch number 6
#  Current loss 0.9509406089782715
#
# Epoch number 6
#  Current loss 0.8881706595420837
#
# Epoch number 6
#  Current loss 1.226182222366333
#
# Epoch number 6
#  Current loss 1.6191966533660889
#
# Epoch number 6
#  Current loss 1.2570620775222778
#
# Epoch number 6
#  Current loss 0.8004810810089111
#
# Epoch number 6
#  Current loss 1.3225727081298828
#
# Epoch number 6
#  Current loss 1.3881617784500122
#
# Epoch number 6
#  Current loss 1.1077885627746582
#
# Epoch number 6
#  Current loss 1.3413524627685547
#
# Epoch number 7
#  Current loss 2.2266523838043213
#
# Epoch number 7
#  Current loss 1.1337779760360718
#
# Epoch number 7
#  Current loss 1.1981513500213623
#
# Epoch number 7
#  Current loss 1.1709988117218018
#
# Epoch number 7
#  Current loss 0.9894319772720337
#
# Epoch number 7
#  Current loss 1.1862422227859497
#
# Epoch number 7
#  Current loss 1.2055466175079346
#
# Epoch number 7
#  Current loss 1.1084237098693848
#
# Epoch number 7
#  Current loss 1.1611076593399048
#
# Epoch number 7
#  Current loss 1.329345941543579
#
# Epoch number 7
#  Current loss 1.2020912170410156
#
# Epoch number 7
#  Current loss 1.188965082168579
#
# Epoch number 7
#  Current loss 1.2072968482971191
#
# Epoch number 7
#  Current loss 1.3754408359527588
#
# Epoch number 7
#  Current loss 1.2602195739746094
#
# Epoch number 8
#  Current loss 1.233910083770752
#
# Epoch number 8
#  Current loss 1.3172461986541748
#
# Epoch number 8
#  Current loss 1.3012865781784058
#
# Epoch number 8
#  Current loss 1.2942956686019897
#
# Epoch number 8
#  Current loss 1.2976943254470825
#
# Epoch number 8
#  Current loss 1.035264015197754
#
# Epoch number 8
#  Current loss 1.0024776458740234
#
# Epoch number 8
#  Current loss 1.6897003650665283
#
# Epoch number 8
#  Current loss 1.0543031692504883
#
# Epoch number 8
#  Current loss 1.2186640501022339
#
# Epoch number 8
#  Current loss 1.2955453395843506
#
# Epoch number 8
#  Current loss 1.2005963325500488
#
# Epoch number 8
#  Current loss 1.166167974472046
#
# Epoch number 8
#  Current loss 1.2492598295211792
#
# Epoch number 8
#  Current loss 1.1501353979110718
#
# Epoch number 9
#  Current loss 1.2262197732925415
#
# Epoch number 9
#  Current loss 1.2844481468200684
#
# Epoch number 9
#  Current loss 1.1385157108306885
#
# Epoch number 9
#  Current loss 1.1463080644607544
#
# Epoch number 9
#  Current loss 1.2565672397613525
#
# Epoch number 9
#  Current loss 0.9248668551445007
#
# Epoch number 9
#  Current loss 1.2368113994598389
#
# Epoch number 9
#  Current loss 1.3437979221343994
#
# Epoch number 9
#  Current loss 1.1581168174743652
#
# Epoch number 9
#  Current loss 1.281555414199829
#
# Epoch number 9
#  Current loss 1.07571280002594
#
# Epoch number 9
#  Current loss 1.3032140731811523
#
# Epoch number 9
#  Current loss 1.1894934177398682
#
# Epoch number 9
#  Current loss 1.2128585577011108
#
# Epoch number 9
#  Current loss 1.3204740285873413
#
# Epoch number 10
#  Current loss 1.436232328414917
#
# Epoch number 10
#  Current loss 1.2678314447402954
#
# Epoch number 10
#  Current loss 1.0317827463150024
#
# Epoch number 10
#  Current loss 0.9178686141967773
#
# Epoch number 10
#  Current loss 1.1681933403015137
#
# Epoch number 10
#  Current loss 1.1701476573944092
#
# Epoch number 10
#  Current loss 1.049346923828125
#
# Epoch number 10
#  Current loss 1.2481143474578857
#
# Epoch number 10
#  Current loss 1.1150825023651123
#
# Epoch number 10
#  Current loss 1.2715766429901123
#
# Epoch number 10
#  Current loss 1.2346022129058838
#
# Epoch number 10
#  Current loss 1.0863981246948242
#
# Epoch number 10
#  Current loss 1.0314946174621582
#
# Epoch number 10
#  Current loss 1.4557158946990967
#
# Epoch number 10
#  Current loss 1.2707726955413818
#
# Epoch number 11
#  Current loss 1.0515930652618408
#
# Epoch number 11
#  Current loss 1.159893274307251
#
# Epoch number 11
#  Current loss 1.0423789024353027
#
# Epoch number 11
#  Current loss 1.2907609939575195
#
# Epoch number 11
#  Current loss 1.2700116634368896
#
# Epoch number 11
#  Current loss 1.2437727451324463
#
# Epoch number 11
#  Current loss 1.2966629266738892
#
# Epoch number 11
#  Current loss 1.2706588506698608
#
# Epoch number 11
#  Current loss 1.2448163032531738
#
# Epoch number 11
#  Current loss 1.5395910739898682
#
# Epoch number 11
#  Current loss 1.0377917289733887
#
# Epoch number 11
#  Current loss 1.200170874595642
#
# Epoch number 11
#  Current loss 1.2287678718566895
#
# Epoch number 11
#  Current loss 0.9203503131866455
#
# Epoch number 11
#  Current loss 1.0622260570526123
#
# Epoch number 12
#  Current loss 1.2911138534545898
#
# Epoch number 12
#  Current loss 1.2828381061553955
#
# Epoch number 12
#  Current loss 1.1804805994033813
#
# Epoch number 12
#  Current loss 1.4700268507003784
#
# Epoch number 12
#  Current loss 1.0659223794937134
#
# Epoch number 12
#  Current loss 1.1322674751281738
#
# Epoch number 12
#  Current loss 1.378895878791809
#
# Epoch number 12
#  Current loss 1.1427748203277588
#
# Epoch number 12
#  Current loss 1.0628138780593872
#
# Epoch number 12
#  Current loss 1.0921159982681274
#
# Epoch number 12
#  Current loss 1.1983240842819214
#
# Epoch number 12
#  Current loss 1.0013892650604248
#
# Epoch number 12
#  Current loss 1.2139387130737305
#
# Epoch number 12
#  Current loss 1.1728304624557495
#
# Epoch number 12
#  Current loss 1.2261896133422852
#
# Epoch number 13
#  Current loss 1.1951649188995361
#
# Epoch number 13
#  Current loss 1.1607762575149536
#
# Epoch number 13
#  Current loss 1.4490667581558228
#
# Epoch number 13
#  Current loss 1.2898584604263306
#
# Epoch number 13
#  Current loss 1.0982303619384766
#
# Epoch number 13
#  Current loss 0.9877671599388123
#
# Epoch number 13
#  Current loss 1.1363128423690796
#
# Epoch number 13
#  Current loss 1.206301212310791
#
# Epoch number 13
#  Current loss 1.4174633026123047
#
# Epoch number 13
#  Current loss 1.2787604331970215
#
# Epoch number 13
#  Current loss 1.1370561122894287
#
# Epoch number 13
#  Current loss 1.0658365488052368
#
# Epoch number 13
#  Current loss 0.9999488592147827
#
# Epoch number 13
#  Current loss 1.3145337104797363
#
# Epoch number 13
#  Current loss 1.2446153163909912
#
# Epoch number 14
#  Current loss 1.1136130094528198
#
# Epoch number 14
#  Current loss 2.232908248901367
#
# Epoch number 14
#  Current loss 1.2423068284988403
#
# Epoch number 14
#  Current loss 0.996687650680542
#
# Epoch number 14
#  Current loss 1.178101897239685
#
# Epoch number 14
#  Current loss 1.268836259841919
#
# Epoch number 14
#  Current loss 1.2907092571258545
#
# Epoch number 14
#  Current loss 1.2798964977264404
#
# Epoch number 14
#  Current loss 1.171688437461853
#
# Epoch number 14
#  Current loss 1.084263801574707
#
# Epoch number 14
#  Current loss 1.2386558055877686
#
# Epoch number 14
#  Current loss 1.2519545555114746
#
# Epoch number 14
#  Current loss 1.7888407707214355
#
# Epoch number 14
#  Current loss 1.2289345264434814
#
# Epoch number 14
#  Current loss 1.0678120851516724
#
# Epoch number 15
#  Current loss 1.1923837661743164
#
# Epoch number 15
#  Current loss 1.1577785015106201
#
# Epoch number 15
#  Current loss 1.0848991870880127
#
# Epoch number 15
#  Current loss 1.344217300415039
#
# Epoch number 15
#  Current loss 1.4722001552581787
#
# Epoch number 15
#  Current loss 0.9797459840774536
#
# Epoch number 15
#  Current loss 1.0811601877212524
#
# Epoch number 15
#  Current loss 1.2275478839874268
#
# Epoch number 15
#  Current loss 1.3608229160308838
#
# Epoch number 15
#  Current loss 1.1891838312149048
#
# Epoch number 15
#  Current loss 1.0420761108398438
#
# Epoch number 15
#  Current loss 1.1816678047180176
#
# Epoch number 15
#  Current loss 1.1433155536651611
#
# Epoch number 15
#  Current loss 1.7369565963745117
#
# Epoch number 15
#  Current loss 1.142805576324463
#
# Epoch number 16
#  Current loss 1.1204659938812256
#
# Epoch number 16
#  Current loss 1.047585368156433
#
# Epoch number 16
#  Current loss 1.4300886392593384
#
# Epoch number 16
#  Current loss 1.2128113508224487
#
# Epoch number 16
#  Current loss 1.2603158950805664
#
# Epoch number 16
#  Current loss 1.3036457300186157
#
# Epoch number 16
#  Current loss 1.2594249248504639
#
# Epoch number 16
#  Current loss 1.054573893547058
#
# Epoch number 16
#  Current loss 1.3477880954742432
#
# Epoch number 16
#  Current loss 1.2531487941741943
#
# Epoch number 16
#  Current loss 1.242789626121521
#
# Epoch number 16
#  Current loss 1.2287869453430176
#
# Epoch number 16
#  Current loss 1.1659870147705078
#
# Epoch number 16
#  Current loss 1.0280957221984863
#
# Epoch number 16
#  Current loss 1.034637212753296
#
# Epoch number 17
#  Current loss 1.222489833831787
#
# Epoch number 17
#  Current loss 1.2250653505325317
#
# Epoch number 17
#  Current loss 1.0239312648773193
#
# Epoch number 17
#  Current loss 1.018639326095581
#
# Epoch number 17
#  Current loss 1.2744135856628418
#
# Epoch number 17
#  Current loss 1.1491379737854004
#
# Epoch number 17
#  Current loss 1.1956017017364502
#
# Epoch number 17
#  Current loss 1.163285255432129
#
# Epoch number 17
#  Current loss 1.3319953680038452
#
# Epoch number 17
#  Current loss 1.2019877433776855
#
# Epoch number 17
#  Current loss 1.1810176372528076
#
# Epoch number 17
#  Current loss 1.0954358577728271
#
# Epoch number 17
#  Current loss 1.188241720199585
#
# Epoch number 17
#  Current loss 1.154946208000183
#
# Epoch number 17
#  Current loss 1.5752432346343994
#
# Epoch number 18
#  Current loss 1.1535680294036865
#
# Epoch number 18
#  Current loss 1.1214263439178467
#
# Epoch number 18
#  Current loss 1.3274736404418945
#
# Epoch number 18
#  Current loss 1.125861406326294
#
# Epoch number 18
#  Current loss 1.0978057384490967
#
# Epoch number 18
#  Current loss 1.2693288326263428
#
# Epoch number 18
#  Current loss 1.2885797023773193
#
# Epoch number 18
#  Current loss 1.2980821132659912
#
# Epoch number 18
#  Current loss 1.3610546588897705
#
# Epoch number 18
#  Current loss 1.370131492614746
#
# Epoch number 18
#  Current loss 1.2275809049606323
#
# Epoch number 18
#  Current loss 1.147641897201538
#
# Epoch number 18
#  Current loss 1.4105665683746338
#
# Epoch number 18
#  Current loss 1.0865089893341064
#
# Epoch number 18
#  Current loss 1.3088196516036987
#
# Epoch number 19
#  Current loss 1.06056809425354
#
# Epoch number 19
#  Current loss 1.3884384632110596
#
# Epoch number 19
#  Current loss 1.0852469205856323
#
# Epoch number 19
#  Current loss 1.1161003112792969
#
# Epoch number 19
#  Current loss 1.0084657669067383
#
# Epoch number 19
#  Current loss 1.7079250812530518
#
# Epoch number 19
#  Current loss 1.205866813659668
#
# Epoch number 19
#  Current loss 1.0143715143203735
#
# Epoch number 19
#  Current loss 1.1562148332595825
#
# Epoch number 19
#  Current loss 1.165856122970581
#
# Epoch number 19
#  Current loss 1.058398723602295
#
# Epoch number 19
#  Current loss 1.033552646636963
#
# Epoch number 19
#  Current loss 1.1668140888214111
#
# Epoch number 19
#  Current loss 1.2533228397369385
#
# Epoch number 19
#  Current loss 1.331742525100708
#
# Model Saved Successfully

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model.load_state_dict(torch.load("model.pt"))
# Out:
# <All keys matched successfully>

# %%
# Load the test dataset
test_dataset = SiameseNetworkDataset(training_csv=testing_csv,training_dir=testing_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# Print the sample outputs to view its dissimilarity
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
    x0, x1 , label = data
    concatenated = torch.cat((x0,x1),0)
    output1,output2 = model(x0.to(device),x1.to(device))
    eucledian_distance = F.pairwise_distance(output1, output2)
    if label==list_0:
        label="Orginial"
    else:
        label="Forged"
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
    counter=counter+1
    if counter ==20:
        break
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
